# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
# To download the original CaseOLAP, not with the modifications made for this project.
#!git clone https://github.com/CaseOLAP/caseolap.git

# %% [markdown]
# #### 1. Download PubMed Documents

# %%
#! python run_download.py

# %% [markdown]
# #### 2. Parse PMIDs

# %%
#Don't do parsing if you already have pubmed.json 
#! python run_parsing.py

# %% [markdown]
# #### 3. Map MeSH terms to PMIDs

# %%
#! python run_mesh2pmid.py

# %% [markdown]
# #### 4. Initialize Index

# %%
! python run_index_init.py
# Out:
# Successfully crested index nd_mito2 , Response: {'acknowledged': True, 'shards_acknowledged': True, 'index': 'nd_mito2'}

# %% [markdown]
# #### 5. Popuate Index

# %%
# !python run_index_populate.py
# Out:
# ['Optic Atrophy, Hereditary, Leber', 'MELAS Syndrome', 'Optic Atrophy, Autosomal Dominant', 'Leigh Disease', 'MERRF Syndrome', 'Kearns-Sayre Syndrome', 'Diffuse Cerebral Sclerosis of Schilder', 'Leukodystrophy, Metachromatic', 'Pyruvate Dehydrogenase Complex Deficiency Disease', 'Ophthalmoplegia, Chronic Progressive External', 'Multiple Sclerosis, Chronic Progressive', 'Multiple Sclerosis', 'Multiple Sclerosis, Relapsing-Remitting', 'Parkinson Disease', 'Amyotrophic Lateral Sclerosis', 'Alzheimer Disease', 'Epilepsy, Generalized', 'Epilepsy, Absence', 'Epilepsy', 'Sudden Unexpected Death in Epilepsy', 'Drug Resistant Epilepsy', 'Epilepsy, Partial, Sensory', 'Epilepsy, Frontal Lobe', 'Epilepsy, Reflex', 'Epilepsy, Temporal Lobe', 'Lafora Disease', 'Epileptic Syndromes', 'Myoclonic Epilepsy, Juvenile', 'Epilepsy, Complex Partial', 'Unverricht-Lundborg Syndrome', 'Lennox Gastaut Syndrome', 'Epilepsy, Post-Traumatic', 'Myoclonic Epilepsies, Progressive', 'Nodding Syndrome', 'Epilepsies, 
# ...

# %% [markdown]
# #### 6. Create Text Cube
# To see analyses on the text documents, see Analyses/Text_Cube_Analyses.
# Some data is already created here.

# %%
# !python run_textcube.py
# Out:
# there are  19 cells in the text cube!
# descendent MeSH terms are being collected....
# Not adding KSS to category 9
# Not adding MERRF Syndrome to category 14
# Not adding MERRF Syndrome to category 14
# Not adding KSS to category 9
# Not adding KSS to category 9
# Not adding KSS to category 9
# Not adding KSS to category 9
# Not adding KSS to category 9
# Not adding KSS to category 9
# Textcube cell to PMID mapping is being created....
# 1000 MeSH descriptors analysed for textcube...!
# 2000 MeSH descriptors analysed for textcube...!
# 3000 MeSH descriptors analysed for textcube...!
# 4000 MeSH descriptors analysed for textcube...!
# 5000 MeSH descriptors analysed for textcube...!
# 6000 MeSH descriptors analysed for textcube...!
# 7000 MeSH descriptors analysed for textcube...!
# 8000 MeSH descriptors analysed for textcube...!
# 9000 MeSH descriptors analysed for textcube...!
# 10000 MeSH descriptors analysed for textcube...!
# 11000 MeSH descriptors analysed for textcube...!
# ...

# %%
###############################################
# Run the API to get all the entity synonyms  #
# if you haven't done so already              #
###############################################

# %% [markdown]
# #### 7. Entity Count

# %%
# !python run_entitycount.py
# Out:
# Entity dictionary is created.......
# Entity count dictionary is initiated.......
# Entity count is running .....
# entity_rep:  P08574
# entity_rep:  P21912
# entity_rep:  Q99807
# entity_rep:  P31040
# entity_rep:  P31930
# entity_rep:  Q5HYK3
# entity_rep:  P08559
# entity_rep:  O75208
# entity_rep:  P52815
# entity_rep:  P30049
# entity_rep:  P20674
# entity_rep:  Q86U28
# entity_rep:  O75439
# entity_rep:  P47985
# entity_rep:  P25705
# entity_rep:  Q02218
# entity_rep:  P11177
# entity_rep:  P22695
# entity_rep:  O14521
# entity_rep:  P82673
# entity_rep:  O14949
# entity_rep:  Q96EL3
# entity_rep:  P11182
# entity_rep:  Q16654
# entity_rep:  P40926
# entity_rep:  Q92552
# entity_rep:  O75390
# entity_rep:  Q9HAV7
# entity_rep:  P10515
# entity_rep:  P42704
# entity_rep:  P36957
# entity_rep:  O00330
# entity_rep:  Q96RP9
# entity_rep:  O95563
# entity_rep:  P28331
# entity_rep:  Q9H2W6
# entity_rep:  P56381
# entity_rep:  Q00325
# entity_rep:  Q9Y3D9
# entity_rep:  P07954
# ...

# %%
#Checking to make sure that all the synonyms from the first step/API are in the final list from the second API
! python 'Analyses/Text_Analyses/check_entity_name_list.py'
# Out:
# Done checking (if there were no issues, nothing else should be printed here)

# %% [markdown]
# #### 8. Update Metadata

# %%
# !python run_metadata_update.py
# Out:
# PMID to entity count count dictionary is being updated.....
# Cell to PMID is updated for entity found PMIDS....
# Cell : LHON includes 119 documents.
# Cell : MELAS includes 123 documents.
# Cell : ADOA includes 208 documents.
# Cell : Leigh includes 406 documents.
# Cell : MERRF includes 46 documents.
# Cell : KSS includes 80 documents.
# Cell : Alpers includes 261 documents.
# Cell : LBSL includes 38 documents.
# Cell : PDD includes 155 documents.
# Cell : PEO includes 169 documents.
# Cell : MS includes 2278 documents.
# Cell : Parkin includes 5799 documents.
# Cell : ALS includes 4026 documents.
# Cell : AD includes 5979 documents.
# Cell : Epil includes 3763 documents.
# Cell : Schiz includes 3554 documents.
# Cell : FA includes 938 documents.
# Cell : HSP includes 215 documents.
# Cell : WD includes 179 documents.

# %% [markdown]
# #### 9. CaseOLAP Scoring

# %%
# Default is on the protein names including MitoCarta, Human UniProt, and comparable Nonhuman UniProt proteins 
# !python run_caseolap_score.py
# Out:
# Total pmids collected for cell:
# LHON 119
# MELAS 123
# ADOA 208
# Leigh 406
# MERRF 46
# KSS 80
# Alpers 261
# LBSL 38
# PDD 155
# PEO 169
# MS 2278
# Parkin 5799
# ALS 4026
# AD 5979
# Epil 3763
# Schiz 3554
# FA 938
# HSP 215
# WD 179
#
# Total entities collected for cell:
# LHON 71
# MELAS 73
# ADOA 45
# Leigh 163
# MERRF 40
# KSS 77
# Alpers 43
# LBSL 20
# PDD 42
# PEO 49
# MS 281
# Parkin 364
# ALS 244
# AD 433
# Epil 371
# Schiz 327
# FA 116
# HSP 78
# WD 79
# total entities collected:  728

# %%
#MitoProteins with MitoCarta and Human UniProt only
total pmids collected for cell -  LHON 97
total pmids collected for cell -  MELAS 89
total pmids collected for cell -  ADOA 206
total pmids collected for cell -  Leigh 352
total pmids collected for cell -  MERRF 36
total pmids collected for cell -  KSS 56
total pmids collected for cell -  Alpers 256
total pmids collected for cell -  LBSL 31
total pmids collected for cell -  PDD 138
total pmids collected for cell -  PEO 148
total pmids collected for cell -  MS 1974
total pmids collected for cell -  Parkin 4925
total pmids collected for cell -  ALS 3708
total pmids collected for cell -  AD 4631
total pmids collected for cell -  Epil 3305
total pmids collected for cell -  Schiz 3221
total pmids collected for cell -  FA 917
total pmids collected for cell -  HSP 200
total pmids collected for cell -  WD 95
total entities collected for cell -  LHON 54
total entities collected for cell -  MELAS 58
total entities collected for cell -  ADOA 35
total entities collected for cell -  Leigh 148
total entities collected for cell -  MERRF 27
total entities collected for cell -  KSS 57
total entities collected for cell -  Alpers 34
total entities collected for cell -  LBSL 14
total entities collected for cell -  PDD 27
total entities collected for cell -  PEO 37
total entities collected for cell -  MS 251
total entities collected for cell -  Parkin 329
total entities collected for cell -  ALS 200
total entities collected for cell -  AD 396
total entities collected for cell -  Epil 335
total entities collected for cell -  Schiz 297
total entities collected for cell -  FA 90
total entities collected for cell -  HSP 68
total entities collected for cell -  WD 57
total entities collected:  699

# %% [markdown]
# # Analyses
# This is if you want to quickly run and save the output data for the following analyses from the Analyses folder. The notebook versions of these files are in the same folders as the .py files. These notebook folders provide better visualization of the files and may be easier for remaking and testing the files if desired. The visualizations should be the same as those in the data files in the 'Data' folder within the folders where the notebooks (.ipynb) and .py files are.

# %% [markdown]
# ### PCA

# %%
# !python 'Analyses/PCA, K-Means, Agglomerative Clustering/PCA_Both_and_Clustering.py'
# Out:
# Number of Clusters 3
# Made PCA...
# Made K-means...
# Made Agglomerative Clustering...
# Finished!

# %%
# !python 'Analyses/PCA, K-Means, Agglomerative Clustering/PCA_Primary.py'
# Out:
# Made PCA of 'Primary' Mitochondrial Diseases...
# Finished!

# %%
# !python 'Analyses/PCA, K-Means, Agglomerative Clustering/PCA_Secondary.py'
# Out:
# Made PCA of 'Secondary' Mitochondrial Diseases...
# Finished!

# %% [markdown]
# ### Hierarchical Clustering

# %%
# !python 'Analyses/Hierarchical Clustering/HierarchicalCluster.py'

# %% [markdown]
# ### Top Entities and Pathways

# %%
# !python 'Analyses/Top Entities, Top Pathways/CaseOLAP_Ranked_Entities_in_Each_Category.py'
# Out:
# Made Top Scores...
# Made Top Entities...
# Heatmap of Top Entities
# Finished!

# %%
# !python 'Analyses/Top Entities, Top Pathways/Popularity_Ranked_Entities_in_Each_Category.py'
# Out:
# Made Top Entities...
# Made Top Counts...
# Finished!

# %%
# !python 'Analyses/Top Entities, Top Pathways/Popularity_Ranked_Pathways_in_Each_Category.py'
# Out:
# Made popularity-ranked pathways...
# Finished!

# %% [markdown]
# ### More Analyses
# For exploring the pathways and constructing a knowledge graph of the proteins, pathways, and interacting proteins, see the Knowledge Graph folder at the top of the directory, one below the root.
# For the protein names (human and comparable nonhuman proteins) and other details surrounding that, see the UniProt API folder in the same directory as the knowledge graph.

# %%
# !python 'Analyses/Text_Analyses/stats_on_full_text_and_abstracts_pmids.py'
# Out:
# Total PMIDs Sorted Through: 33000000
# Title PMIDs:  33169281
# Abstract PMIDs:  22160660
# Full text PMIDs:  54918
#
# ND Mito PMIDs:  460932
# Titles in indexed database:  451364 / 460932  =  97.92 %
# Abstracts in indexed database:  199515 / 460932  =  43.29 %
# Full text in indexed database:  0 / 460932  =  0.0 %
#
#
# ND Mito PMIDs Used:  24385
# Titles *used* in indexed database:  23513 / 24385  =  96.41999999999999 %
# Abstracts *used* in indexed database:  12428 / 24385  =  50.970000000000006 %
# Full text *used* in indexed database:  0 / 24385  =  0.0 %
