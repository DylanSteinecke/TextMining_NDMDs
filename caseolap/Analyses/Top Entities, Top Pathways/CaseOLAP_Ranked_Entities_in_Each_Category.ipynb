# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# Entities Ranked By Top CaseOLAP Score

# Use the notebook to see a nicer display of the dataframes, particularly the heatmap
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

scores = pd.read_csv('../../result/caseolap.csv')
cols = list(scores.columns)
entities = cols[0]

top_scores = pd.DataFrame(columns = cols)
for i in range(0,len(scores)):
    top_scores = top_scores.append(pd.Series(0.0, index=cols), ignore_index=True)
top_scores.columns = cols
top_scores = top_scores.drop(['protein'], axis=1)       #<---switch out with the entity column name depending on your entity
top_entities = top_scores.copy()

for i in range(1,len(cols)):
    categ_scores = list(scores[cols[i]])
    end = len(categ_scores)
    
    for j in range(0,len(categ_scores)):
        TOP = max(categ_scores)
        if(TOP == 0.0): break
        TOP_ind = categ_scores.index(TOP)
        top_scores.iloc[j,i-1] = TOP
        top_entities.iloc[j,i-1] = scores[entities][TOP_ind]
        categ_scores[TOP_ind] = -1
        
top_scores.index = range(1,end+1)
print('Top Scores')
display(top_scores)
top_scores.to_csv('Data/top_scores.csv')

top_entities.index = range(1,end+1)
print('Top Entities')
display(top_entities)
top_entities.to_csv('Data/top_entities.csv')

alltop_entities = set()
for row in range(1,end+1):
    for col in top_entities.columns:
        alltop_entities.add(top_entities.loc[row,col])
        
total_top = 0
for i in range(1,len(top_entities)):
    for col in top_entities.columns:
        if(top_entities[col][i] != '0.0'):
            total_top += 1
        
unique_top = len(alltop_entities)
#print('Unique Entities / Total Entities in Top in all categories (i.e. all nonzero entries): ', unique_top, '/', total_top)

print('Heatmap of Top Entities')
df = top_scores
display(df.style.background_gradient(cmap ='Reds')\
        .set_properties(**{'font-size': '10px'}))
# Out:
# <style>.container { width:90% !important; }</style>
# Top Scores
#          LHON     MELAS      ADOA     Leigh     MERRF       KSS    Alpers  \
# 1    0.067128  0.048236  0.280080  0.097306  0.086958  0.079369  0.227914
# 2    0.050426  0.038081  0.047811  0.087156  0.086670  0.068835  0.131850
# 3    0.046357  0.036049  0.031363  0.084086  0.045544  0.063008  0.098291
# 4    0.038992  0.033054  0.027300  0.082589  0.041285  0.061706  0.073094
# 5    0.028219  0.032371  0.019381  0.078762  0.040963  0.060608  0.043089
# ..        ...       ...       ...       ...       ...       ...       ...
# 724  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 725  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 726  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 727  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 728  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#          LBSL       PDD       PEO        MS    Parkin       ALS        AD  \
# 1    0.127713  0.236665  0.181252  0.121327  0.253433  0.204669  0.110236
# 2    0.065774  0.146183  0.180911  0.090841  0.179245  0.154485  0.087898
# 3    0.037968  0.133585  0.083389  0.077288  0.173782  0.044139  0.086942
# 4    0.034443  0.039497  0.045173  0.071402  0.136142  0.034989  0.081615
# 5    0.021944  0.036890  0.043674  0.059330  0.130100  0.034321  0.081061
# ..        ...       ...       ...       ...       ...       ...       ...
# 724  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 725  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 726  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 727  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 728  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#          Epil     Schiz        FA       HSP        WD
# 1    0.173541  0.182748  0.307748  0.188174  0.052904
# 2    0.093236  0.106608  0.041961  0.103782  0.047869
# 3    0.089828  0.095144  0.041689  0.070050  0.044920
# 4    0.085322  0.093123  0.041532  0.051541  0.038607
# 5    0.069670  0.089719  0.021640  0.034556  0.038552
# ..        ...       ...       ...       ...       ...
# 724  0.000000  0.000000  0.000000  0.000000  0.000000
# 725  0.000000  0.000000  0.000000  0.000000  0.000000
# 726  0.000000  0.000000  0.000000  0.000000  0.000000
# 727  0.000000  0.000000  0.000000  0.000000  0.000000
# 728  0.000000  0.000000  0.000000  0.000000  0.000000
#
# [728 rows x 19 columns]
# Top Entities
#        LHON   MELAS    ADOA   Leigh   MERRF     KSS  Alpers    LBSL     PDD  \
# 1    P03886  P99999  O60313  Q15526  Q96E11  Q96RR1  P33897  Q9NZJ7  Q9P0J1
# 2    P03905  P31040  Q9H6K4  P20674  Q969S9  P54098  P30044  P33897  P08559
# 3    Q16795  P54098  O95140  P36551  P10176  P20674  P54098  Q9NYZ2  Q8N490
# 4    P03923  P20674  O00429  P10176  P20674  P36551  Q9Y276  P22557  O00330
# 5    Q9NWT8  P36551  Q04837  P99999  P99999  P10176  P06746  Q86U28  P09622
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 724       0       0       0       0       0       0       0       0       0
# 725       0       0       0       0       0       0       0       0       0
# 726       0       0       0       0       0       0       0       0       0
# 727       0       0       0       0       0       0       0       0       0
# 728       0       0       0       0       0       0       0       0       0
#
#         PEO      MS  Parkin     ALS      AD    Epil   Schiz      FA     HSP  \
# 1    P54098  P30044  O60260  P00441  P42574  O60220  P21964  Q16595  Q9UQ90
# 2    Q96RR1  O15528  Q9BXM7  P04179  O00154  P40939  Q8WUD6  Q99798  Q9H9B4
# 3    P12235  Q9NYZ2  Q99497  Q8N490  P00441  O95822  Q13423  Q8N4E7  P10809
# 4    P06746  Q9BYT8  P52758  Q9BYT8  P20674  Q8N0X4  Q13085  P02794  P54886
# 5    P99999  O43678  P27338  Q9NYZ2  P36551  P49419  Q9HCC0  Q9NTG7  Q9Y4W6
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 724       0       0       0       0       0       0       0       0       0
# 725       0       0       0       0       0       0       0       0       0
# 726       0       0       0       0       0       0       0       0       0
# 727       0       0       0       0       0       0       0       0       0
# 728       0       0       0       0       0       0       0       0       0
#
#          WD
# 1    P00505
# 2    P00441
# 3    P04179
# 4    P02794
# 5    Q8N4E7
# ..      ...
# 724       0
# 725       0
# 726       0
# 727       0
# 728       0
#
# [728 rows x 19 columns]
# Heatmap of Top Entities
# <style  type="text/css" >
# #T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col0,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col1,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col2,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col3,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col4,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col5,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col6,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col7,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col8,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col9,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col10,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col11,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col12,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col13,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col14,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col15,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col16,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col17,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row0_col18,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col4,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col9{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col0{
#             background-color:  #ca181d;
#             color:  #f1f1f1;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col1{
#             background-color:  #be151a;
#             color:  #f1f1f1;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col2,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row3_col12,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row4_col7,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row14_col11,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row25_col15,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row27_col3,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row28_col3,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row29_col3,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row30_col3,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row38_col18,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row39_col14,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row53_col1,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row54_col1,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row59_col10,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row60_col10,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row61_col10,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row62_col10,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row98_col13,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row99_col13{
#             background-color:  #fdd3c1;
#             color:  #000000;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col3{
#             background-color:  #9a0c14;
#             color:  #f1f1f1;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col5{
#             background-color:  #a60f15;
#             color:  #f1f1f1;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col6,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row3_col0{
#             background-color:  #f34c37;
#             color:  #000000;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col7,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row4_col11,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row8_col1{
#             background-color:  #fa6547;
#             color:  #000000;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col8{
#             background-color:  #f03d2d;
#             color:  #f1f1f1;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col10,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row2_col1{
#             background-color:  #cb181d;
#             color:  #f1f1f1;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col11{
#             background-color:  #d72322;
#             color:  #f1f1f1;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col12{
#             background-color:  #c9181d;
#             color:  #f1f1f1;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col13{
#             background-color:  #bc141a;
#             color:  #f1f1f1;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col14,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row3_col11{
#             background-color:  #f75c41;
#             color:  #000000;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col15{
#             background-color:  #f34a36;
#             color:  #000000;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col16,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row2_col16,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row3_col16,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row8_col7,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row9_col9,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row17_col4,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row22_col11,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row32_col5,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row38_col0,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row39_col0,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row39_col15,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row40_col0,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row40_col15,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row41_col15,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row42_col15,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row43_col15,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row48_col3,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row49_col3,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row57_col14,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row58_col14,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row59_col14,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row88_col10,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row89_col10,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row90_col10,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row91_col10,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row92_col10,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row141_col13,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row142_col13,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row143_col13,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row144_col13,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row145_col13{
#             background-color:  #fedecf;
#             color:  #000000;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col17,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row16_col13{
#             background-color:  #f6563d;
#             color:  #000000;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row1_col18{
#             background-color:  #960b13;
#             color:  #f1f1f1;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row2_col0{
#             background-color:  #dc2924;
#             color:  #f1f1f1;
#             font-size:  10px;
#         }#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row2_col2,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row7_col17,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row13_col12,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row14_col12,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row15_col12,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row19_col4,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row27_col11,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row28_col11,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row43_col5,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row46_col0,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row61_col15,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row62_col15,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row63_col15,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row64_col1,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row64_col15,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row65_col1,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row65_col15,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row66_col1,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row66_col15,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row67_col1,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row67_col15,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row68_col1,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row68_col15,#T_ba131e14_05d5_11ec_9c9b_02173c5425d4row69_col15,#T_ba131e14_05d5_11ec_9c9b_02173

# %%
top_entities = pd.read_csv('Data/top_entities.csv')
top_entities.head(13)
# Out:
#     Unnamed: 0    LHON   MELAS    ADOA   Leigh   MERRF     KSS  Alpers  \
# 0            1  P03886  P99999  O60313  Q15526  Q96E11  Q96RR1  P33897
# 1            2  P03905  P31040  Q9H6K4  P20674  Q969S9  P54098  P30044
# 2            3  Q16795  P54098  O95140  P36551  P10176  P20674  P54098
# 3            4  P03923  P20674  O00429  P10176  P20674  P36551  Q9Y276
# 4            5  Q9NWT8  P36551  Q04837  P99999  P99999  P10176  P06746
# 5            6  O60313  P10176  Q9BT17  P42704  P36551  P99999  O95363
# 6            7  P00846  Q969S9  Q12983  P00846  Q5HYK3  Q96E11  P04040
# 7            8  Q9H300  Q96RR1  Q99623  O43181  O00142  Q969S9  P09110
# 8            9  Q12983  Q96E11  P35232  P30084  O43819  P21912  P43155
# 9           10  P03915  P00846  Q96RR1  Q6NVY1  Q9Y2D0  Q9UDR5  Q6IB77
# 10          11  Q16611  P21912  Q96AG3  Q330K2  P35218  Q9UL12  P99999
# 11          12  Q8WWV3  Q9UDR5  P30536  O43819  P54098  P00156  P55084
# 12          13  O00408  Q9UL12  P99999  O00217  Q02318  P31040  P42765
#
#       LBSL     PDD     PEO      MS  Parkin     ALS      AD    Epil   Schiz  \
# 0   Q9NZJ7  Q9P0J1  P54098  P30044  O60260  P00441  P42574  O60220  P21964
# 1   P33897  P08559  Q96RR1  O15528  Q9BXM7  P04179  O00154  P40939  Q8WUD6
# 2   Q9NYZ2  Q8N490  P12235  Q9NYZ2  Q99497  Q8N490  P00441  O95822  Q13423
# 3   P22557  O00330  P06746  Q9BYT8  P52758  Q9BYT8  P20674  Q8N0X4  Q13085
# 4   Q86U28  P09622  P99999  O43678  P27338  Q9NYZ2  P36551  P49419  Q9HCC0
# 5   Q9NP58  P11177  P20674  P30536  P21964  Q8WYQ3  P10176  P12236  P52758
# 6   Q9Y2D0  P11498  P10176  O43676  P42574  P38646  P10415  Q53FZ2  Q6IB77
# 7   P35218  Q86WU2  P36551  P32119  Q9BT17  P42574  Q9Y2S7  P12235  Q9UG56
# 8   Q14249  P30084  Q9UHN1  P38646  P00441  P10415  O43676  Q6IB77  O43272
# 9   P53701  Q02218  O94761  Q99797  P10415  Q16762  P32119  P25325  P04040
# 10  Q99797  P29803  P12236  Q8N4E7  P02794  Q8NFU3  P52758  P48728  O00154
# 11  P06746  P99999  Q96E11  P02794  P21397  Q99797  P14735  P13804  P43155
# 12  O00408  P10515  Q969S9  P10415  Q8N4E7  Q9Y2S7  Q07812  O43676  P21397
#
#         FA     HSP      WD
# 0   Q16595  Q9UQ90  P00505
# 1   Q99798  Q9H9B4  P00441
# 2   Q8N4E7  P10809  P04179
# 3   P02794  P54886  P02794
# 4   Q9NTG7  Q9Y4W6  Q8N4E7
# 5   Q15070  P30044  P10515
# 6   Q16798  Q9H6K4  P32119
# 7   P23368  P41250  P07203
# 8   Q9H1K1  P33897  Q9BYT8
# 9   P09622  Q9H3J6  P36969
# 10  Q9HD34  Q9BRQ8  Q16854
# 11  Q9Y697  P61604  P04040
# 12  Q14296  Q96IR7  Q9NYZ2

# %%
total_instances = 0
for i in range(1,len(top_entities)):
    for col in top_entities.columns[1:20]:
        if(top_entities[col][i] != '0.0'):
            total_instances += 1
total_top = total_instances
total_top
# Out:
# 2897
